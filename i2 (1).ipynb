# %%
import os
import xml.etree.ElementTree as ET
import cv2
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from PIL import Image
from sklearn.model_selection import train_test_split
import random

# %%
ann_dir = 'VOC2012/Annotations'
img_dir = 'VOC2012/JPEGImages'

def draw_boxes(image_path, annotation_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    tree = ET.parse(annotation_path)
    root = tree.getroot()
    for obj in root.findall('object'):
        label = obj.find('name').text
        bbox = obj.find('bndbox')
        x1 = int(bbox.find('xmin').text)
        y1 = int(bbox.find('ymin').text)
        x2 = int(bbox.find('xmax').text)
        y2 = int(bbox.find('ymax').text)
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(image, label, (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)
    return image

# %%
test_img = '2007_000032.jpg'
img_path = os.path.join(img_dir, test_img)
ann_path = os.path.join(ann_dir, test_img.replace('.jpg', '.xml'))

img = draw_boxes(img_path, ann_path)
plt.imshow(img)
plt.axis('off')
plt.title("Object Detection")
plt.show()

# %%
def build_unet(input_shape=(128, 128, 3), num_classes=21):
    inputs = Input(input_shape)
    c1 = Conv2D(32, 3, activation='relu', padding='same')(inputs)
    c1 = Conv2D(32, 3, activation='relu', padding='same')(c1)
    p1 = MaxPooling2D()(c1)

    c2 = Conv2D(64, 3, activation='relu', padding='same')(p1)
    c2 = Conv2D(64, 3, activation='relu', padding='same')(c2)
    p2 = MaxPooling2D()(c2)

    c3 = Conv2D(128, 3, activation='relu', padding='same')(p2)
    c3 = Conv2D(128, 3, activation='relu', padding='same')(c3)

    u1 = Conv2DTranspose(64, 2, strides=2, padding='same')(c3)
    u1 = concatenate([u1, c2])
    c4 = Conv2D(64, 3, activation='relu', padding='same')(u1)

    u2 = Conv2DTranspose(32, 2, strides=2, padding='same')(c4)
    u2 = concatenate([u2, c1])
    c5 = Conv2D(32, 3, activation='relu', padding='same')(u2)

    outputs = Conv2D(num_classes, 1, activation='softmax')(c5)
    return Model(inputs, outputs)

unet_model = build_unet()
unet_model.compile(optimizer='adam', loss='categorical_crossentropy')
unet_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │     36,928 │ conv2d_2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 64, 64,    │     32,832 │ conv2d_5[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │     73,792 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 128, 128,  │      8,224 │ conv2d_6[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 128, 128,  │     18,464 │ concatenate_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 128, 128,  │        693 │ conv2d_7[0][0]    │
# │                     │ 21)               │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 421,013 (1.61 MB)
#  Trainable params: 421,013 (1.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def extract_labels(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    labels = [obj.find('name').text for obj in root.findall('object')]
    return list(set(labels))

# %%
def generate_caption_from_objects(labels):
    if not labels:
        return "an image with no detectable objects"
    elif len(labels) == 1:
        return f"a {labels[0]}"
    else:
        return f"a {', '.join(labels[:-1])} and {labels[-1]}"

# %%
labels = extract_labels(ann_path)
caption = generate_caption_from_objects(labels)

print("Detected objects:", labels)
print("Generated caption:", caption)

img = draw_boxes(img_path, ann_path)
plt.imshow(img)
plt.axis('off')
plt.title(caption)
plt.show()
# Out:
# Detected objects: ['person', 'aeroplane']
# Generated caption: a person and aeroplane

# %%
seg_img_dir = 'VOC2012/JPEGImages'
seg_mask_dir = 'VOC2012/SegmentationClass'

# Filter out images that have masks
image_ids = [f[:-4] for f in os.listdir(seg_mask_dir) if f.endswith('.png')]
print("Total segmentation samples:", len(image_ids))
# Out:
# Total segmentation samples: 2913

# %%
IMG_SIZE = 128
NUM_CLASSES = 21  # Pascal VOC classes

def load_image(path):
    img = Image.open(path).resize((IMG_SIZE, IMG_SIZE))
    return np.array(img)

def load_mask(path):
    mask = Image.open(path).resize((IMG_SIZE, IMG_SIZE), resample=Image.NEAREST)
    mask = np.array(mask)
    return to_categorical(mask, num_classes=NUM_CLASSES)

X, Y = [], []
for img_id in image_ids[:200]:  # You can increase this for full training
    img_path = os.path.join(seg_img_dir, f"{img_id}.jpg")
    mask_path = os.path.join(seg_mask_dir, f"{img_id}.png")
    try:
        X.append(load_image(img_path))
        Y.append(load_mask(mask_path))
    except:
        continue

X = np.array(X) / 255.0
Y = np.array(Y)
print("Shapes:", X.shape, Y.shape)
# Out:
# Shapes: (200, 128, 128, 3) (0,)

# %%
X, Y = [], []
for img_id in image_ids[:200]:
    img_path = os.path.join(seg_img_dir, f"{img_id}.jpg")
    mask_path = os.path.join(seg_mask_dir, f"{img_id}.png")
    try:
        image = load_image(img_path)
        mask = load_mask(mask_path)
        if mask.shape[:2] != (IMG_SIZE, IMG_SIZE):
            continue
        X.append(image)
        Y.append(mask)
    except Exception as e:
        print(f"Skipping {img_id}: {e}")
# Out:
# Skipping 2007_000032: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000033: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000039: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000042: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000061: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000063: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000068: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000121: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000123: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000129: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000170: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000175: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000187: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000241: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000243: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000250: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000256: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000323: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000332: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000333: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000346: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000363: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000364: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000392: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000452: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000464: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000480: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000491: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000504: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000515: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000528: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000529: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000549: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000559: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000572: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000584: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000629: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000636: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000645: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000648: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000661: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000663: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000676: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000713: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000720: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000727: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000733: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000738: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000762: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000768: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000783: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000793: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000799: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000804: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000822: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000830: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000836: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000837: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000847: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000862: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000876: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000904: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000925: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_000999: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001027: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001073: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001149: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001154: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001175: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001185: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001225: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001239: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001284: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001288: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001289: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001299: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001311: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001321: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001340: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001377: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001397: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001408: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001416: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001420: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001423: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001430: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001439: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001457: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001458: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001487: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001526: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001568: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001585: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001586: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001587: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001594: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001595: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001602: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001609: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001630: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001677: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001678: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001698: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001704: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001709: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001717: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001724: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001733: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001761: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001763: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001764: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001774: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001825: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001834: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001857: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001872: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001884: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001901: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001917: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001955: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_001960: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002024: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002046: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002055: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002088: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002094: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002099: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002105: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002107: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002119: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002120: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002132: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002142: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002198: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002212: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002216: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002227: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002234: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002260: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002266: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002268: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002273: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002281: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002284: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002293: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002361: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002368: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002370: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002376: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002378: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002387: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002400: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002403: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002412: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002426: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002427: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002445: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002462: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002470: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002488: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002539: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002545: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002565: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002597: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002611: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002618: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002619: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002624: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002639: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002643: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002648: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002668: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002669: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002719: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002728: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002760: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002789: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002823: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002824: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002845: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002852: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002895: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002896: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002903: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002914: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002953: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002954: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_002967: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_003000: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_003011: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_003020: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_003022: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_003051: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_003088: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_003101: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_003106: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_003110: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_003118: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_003131: index 255 is out of bounds for axis 1 with size 21
# Skipping 2007_003134: index 255 is out of bounds for axis 1 with size 21

# %%
VOC_COLORMAP = {
    (128, 0, 0): 0, (0, 128, 0): 1, (128, 128, 0): 2, (0, 0, 128): 3,
    (128, 0, 128): 4, (0, 128, 128): 5, (128, 128, 128): 6, (64, 0, 0): 7,
    (192, 0, 0): 8, (64, 128, 0): 9, (192, 128, 0): 10, (64, 0, 128): 11,
    (192, 0, 128): 12, (64, 128, 128): 13, (192, 128, 128): 14,
    (0, 64, 0): 15, (128, 64, 0): 16, (0, 192, 0): 17, (128, 192, 0): 18,
    (0, 64, 128): 19, (128, 64, 128): 20
}

def rgb_to_class(mask):
    h, w, _ = mask.shape
    class_mask = np.zeros((h, w), dtype=np.uint8)
    for rgb, class_id in VOC_COLORMAP.items():
        match = np.all(mask == rgb, axis=-1)
        class_mask[match] = class_id
    return class_mask

# %%
X, Y = [], []
for img_id in image_ids[:200]:
    img_path = os.path.join(seg_img_dir, f"{img_id}.jpg")
    mask_path = os.path.join(seg_mask_dir, f"{img_id}.png")
    try:
        img = Image.open(img_path).resize((IMG_SIZE, IMG_SIZE))
        mask = Image.open(mask_path).resize((IMG_SIZE, IMG_SIZE), resample=Image.NEAREST)
        img = np.array(img)
        mask = np.array(mask)
        if mask.ndim == 3:  # RGB mask
            mask = rgb_to_class(mask)
        X.append(img)
        Y.append(mask)
    except Exception as e:
        print(f"Skipping {img_id} due to: {e}")

# %%
X = np.array(X) / 255.0
Y = np.array(Y)
Y[Y == 255] = 0  # Replace ignore label with background (class 0)
Y = to_categorical(Y, num_classes=NUM_CLASSES)

print("Loaded:", X.shape, Y.shape)
# Out:
# Loaded: (200, 128, 128, 3) (200, 128, 128, 21)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2, random_state=42)

print("Train:", X_train.shape, Y_train.shape)
print("Val:  ", X_val.shape, Y_val.shape)
# Out:
# Train: (160, 128, 128, 3) (160, 128, 128, 21)
# Val:   (40, 128, 128, 3) (40, 128, 128, 21)

# %%
history = unet_model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    batch_size=8,
    epochs=25,
    verbose=1
)
# Out:
# Epoch 1/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 306ms/step - loss: 2.5862 - val_loss: 1.7019
# Epoch 2/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 289ms/step - loss: 1.5676 - val_loss: 1.3472
# Epoch 3/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 285ms/step - loss: 1.4733 - val_loss: 1.2529
# Epoch 4/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 339ms/step - loss: 1.3231 - val_loss: 1.2024
# Epoch 5/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 383ms/step - loss: 1.2529 - val_loss: 1.2069
# Epoch 6/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 352ms/step - loss: 1.3098 - val_loss: 1.1630
# Epoch 7/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - loss: 1.2061 - val_loss: 1.1690
# Epoch 8/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 332ms/step - loss: 1.2849 - val_loss: 1.1470
# Epoch 9/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - loss: 1.2218 - val_loss: 1.2319
# Epoch 10/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 308ms/step - loss: 1.2590 - val_loss: 1.1575
# Epoch 11/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - loss: 1.2370 - val_loss: 1.1528
# Epoch 12/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 308ms/step - loss: 1.2524 - val_loss: 1.1403
# Epoch 13/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 310ms/step - loss: 1.2190 - val_loss: 1.1409
# Epoch 14/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 309ms/step - loss: 1.3202 - val_loss: 1.2014
# Epoch 15/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - loss: 1.2630 - val_loss: 1.1786
# Epoch 16/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 306ms/step - loss: 1.2314 - val_loss: 1.1564
# Epoch 17/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 306ms/step - loss: 1.1814 - val_loss: 1.1888
# Epoch 18/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 303ms/step - loss: 1.2634 - val_loss: 1.1402
# Epoch 19/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 306ms/step - loss: 1.3160 - val_loss: 1.1346
# Epoch 20/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 308ms/step - loss: 1.1759 - val_loss: 1.1504
# Epoch 21/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 311ms/step - loss: 1.1711 - val_loss: 1.1302
# Epoch 22/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 302ms/step - loss: 1.1430 - val_loss: 1.1338
# Epoch 23/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 307ms/step - loss: 1.2384 - val_loss: 1.1330
# Epoch 24/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 304ms/step - loss: 1.1553 - val_loss: 1.1513
# Epoch 25/25
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 304ms/step - loss: 1.2204 - val_loss: 1.1322

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("U-Net Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
def visualize_segmentation(index=0):
    pred = unet_model.predict(X_val[index][np.newaxis, ...])
    pred_mask = np.argmax(pred[0], axis=-1)
    true_mask = np.argmax(Y_val[index], axis=-1)

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 3, 1)
    plt.imshow(X_val[index])
    plt.title("Input Image")
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.imshow(true_mask)
    plt.title("True Mask")
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask)
    plt.title("Predicted Mask")
    plt.axis('off')

    plt.tight_layout()
    plt.show()

visualize_segmentation(0)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step

# %%
VOC_COLORS = np.array([
    [128, 0, 0], [0, 128, 0], [128, 128, 0], [0, 0, 128], [128, 0, 128],
    [0, 128, 128], [128, 128, 128], [64, 0, 0], [192, 0, 0], [64, 128, 0],
    [192, 128, 0], [64, 0, 128], [192, 0, 128], [64, 128, 128], [192, 128, 128],
    [0, 64, 0], [128, 64, 0], [0, 192, 0], [128, 192, 0], [0, 64, 128],
    [128, 64, 128]
], dtype=np.uint8)

# %%
def decode_segmentation(mask):
    color_mask = VOC_COLORS[mask]
    return color_mask

def overlay_mask(image, mask, alpha=0.5):
    mask_color = decode_segmentation(mask)
    overlay = (alpha * image + (1 - alpha) * mask_color).astype(np.uint8)
    return overlay

# %%
def show_overlay(index=0):
    image = (X_val[index] * 255).astype(np.uint8)
    pred = unet_model.predict(X_val[index][np.newaxis])[0]
    pred_mask = np.argmax(pred, axis=-1)

    overlay = overlay_mask(image, pred_mask)

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 3, 1)
    plt.imshow(image)
    plt.title("Original Image")
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.imshow(pred_mask)
    plt.title("Predicted Mask")
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.imshow(overlay)
    plt.title("Overlay")
    plt.axis('off')
    plt.show()

show_overlay(0)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step

# %%
def final_visualization(img_id):
    img_path = os.path.join(img_dir, f"{img_id}.jpg")
    xml_path = os.path.join(ann_dir, f"{img_id}.xml")

    original_img = cv2.imread(img_path)
    original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
    resized_img = cv2.resize(original_img, (IMG_SIZE, IMG_SIZE))

    detected_img = draw_boxes(img_path, xml_path)
    detected_img = cv2.resize(detected_img, (IMG_SIZE, IMG_SIZE))

    input_img = resized_img.astype(np.float32) / 255.0
    pred = unet_model.predict(input_img[np.newaxis, ...])[0]
    pred_mask = np.argmax(pred, axis=-1)
    overlay_img = overlay_mask(resized_img, pred_mask)

    labels = extract_labels(xml_path)
    caption = generate_caption_from_objects(labels)

    plt.figure(figsize=(8, 15))

    plt.subplot(1, 3, 1)
    plt.imshow(detected_img)
    plt.title("Object Detection")
    plt.axis('off')

    # plt.subplot(1, 3, 2)
    # plt.imshow(pred_mask)
    # plt.title("Segmentation Mask")
    # plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.imshow(overlay_img)
    plt.title(f"Caption: {caption}")
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
sample_ids = [f[:-4] for f in os.listdir(img_dir) if f.endswith('.jpg')]
random_samples = random.sample(sample_ids, 5)
print("Try any of these:", random_samples)
# Out:
# Try any of these: ['2008_007286', '2011_000071', '2010_002191', '2012_003628', '2007_006260']

# %%
final_visualization("2008_003746")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step

# %%
final_visualization("2007_001630")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
